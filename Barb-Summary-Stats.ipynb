# %%
# Scheme Management Inclusive

#Libraries
import pandas as pd
import numpy as np
from sklearn import tree
import random
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# Read in Training Data
trainingValues = pd.read_csv('training-values.csv')
#print trainingValues[1:15]

# %%
# Amount TSH
tsh = trainingValues['amount_tsh']
tsh = tsh[tsh <5000]
#print tsh
atsh = plt.figure();
tsh.hist(bins=30)
atsh.savefig('amount-tsh-histogram.png')

# %%
fivesum = trainingValues.describe()
fivesum
fivesum.to_csv('five-number-summary.csv')

# %%
# GPS Height
gps = trainingValues['gps_height']
#print tsh
gpsh = plt.figure();
gps.hist()
gpsh.savefig('gps-height-histogram.png')

# %%
# Longitude
longitude = trainingValues['longitude']
#print tsh
longi = plt.figure();
longitude.hist()
longi.savefig('longitude-histogram.png')

# %%
# Latitude
lat = trainingValues['latitude']
#print tsh
lati = plt.figure();
lat.hist()
lati.savefig('latitude-histogram.png')

# %%
# Num Private
private = trainingValues['num_private']
#print tsh
priv = plt.figure();
private.hist()
priv.savefig('private-num-histogram.png')

# %%
# Region Code
region = trainingValues['region_code']
#print tsh
reg = plt.figure();
region.hist()
reg.savefig('region-code-histogram.png')

# %%
# District Code
dist = trainingValues['district_code']
#print tsh
district = plt.figure();
dist.hist()
district.savefig('district-code-histogram.png')

# %%
# Population
pop = trainingValues['population']
#print tsh
popul = plt.figure();
pop.hist()
popul.savefig('population.png')

# %%
# Construction Year
construction = trainingValues['construction_year']
#print tsh
cons = plt.figure();
construction.hist()
cons.savefig('construction-year.png')
